# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet, stopwords
from nltk.stem import WordNetLemmatizer
import gensim

# 下載必要的資源
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# pos_tag change
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN


# def load_sentiment_words(sentiment_dic):
#     f = pd.ExcelFile(sentiment_dic)
#     df = f.parse()
#     positive_words = set(df.iloc[:, 1].dropna().astype(str))
#     negative_words = set(df.iloc[:, 0].dropna().astype(str))
#     return positive_words, negative_words

# %%
def load_sentiment_words_2(sentiment_dic):
    f = pd.ExcelFile(sentiment_dic)
    df = f.parse()

    df.iloc[:, 1] = df.iloc[:, 1].dropna()  
    df.iloc[:, 0] = df.iloc[:, 0].dropna()

    df.iloc[:, 1] = df.iloc[:, 1].astype(str)  
    df.iloc[:, 0] = df.iloc[:, 0].astype(str)

    df.iloc[:, 1] = df.iloc[:, 1].apply(lambda x: x.lower()) 
    df.iloc[:, 0] = df.iloc[:, 0].apply(lambda x: x.lower()) 

    positive_words = set(df.iloc[:, 1])
    negative_words = set(df.iloc[:, 0])
    return positive_words, negative_words

# %% [markdown]
# #### **1. `gensim.utils.simple_preprocess()`**
#
# - **優點**：
#   - 自動將轉換小寫。
#   - 去除標點符號和非字母字符（ `deacc=True`）。
#   - 高效，適合處理大規模文本。
#
# - **缺點**：
#   - 不保留數字和標點符號。
#   - 不會自動去除停用詞。
#   - 靈活性有限。
#
# #### **2. `nltk.tokenize.word_tokenize()`**
#
# - **優點**：
#   - 能夠保留標點符號、數字等字符。
#   - 適合需要進一步自定義處理的情況。
#   - 支援多語言文本。
#
# - **缺點**：
#   - 僅做分詞，不進行其他預處理 (如轉換小寫或去除標點)。
#
# - **適用場景**：
#   - 需要更精細的分詞操作，尤其是保留標點符號、數字或在多語言環境下進行處理時。

# %%
stop_words = set(stopwords.words('english')) # list -> set
print(type(stop_words))
print(stop_words)
# Out:
# <class 'set'>
# {'me', 'don', 'by', 'who', 'o', 'ours', 'its', 'they', 'were', 'didn', 'very', 'doesn', 'when', 'as', 'of', 'most', "couldn't", 'here', "hadn't", "you'll", 'with', 'is', 'down', "hasn't", "isn't", 'your', 'once', 'on', 'or', 'yourself', "should've", 'that', 'below', 'whom', 'over', 'where', 'what', 'can', 'further', 'm', 'ourselves', 'his', "needn't", 'if', 'yourselves', 't', 'an', 'those', 'nor', "mightn't", 'himself', 'into', 'few', "wouldn't", 'her', 'herself', 'and', 'i', "it's", 'will', 'won', 'both', 'aren', 'wouldn', 'theirs', 'couldn', 'too', "shouldn't", 'for', 'up', 'which', 'hasn', 'own', 'after', "didn't", 'ma', 'each', 'haven', "you'd", 'such', 'until', 'out', 'these', "doesn't", 'now', 'did', 'isn', 'why', 'do', 'again', "she's", 'during', 'him', 'at', "aren't", 'in', "haven't", 'above', 'weren', 'hadn', 'my', "shan't", "that'll", 'd', 'a', 'before', 'he', 've', 'off', 'be', 'while', 'shan', 'myself', 'under', 'been', 'has', "you've", 'there', 'all', "wasn't", 'doing', 'because', 'so', 'then', 'against', 'more', 'than', "don't", "you're", 'no', 'through', 'but', 'only', 'we', 'just', 'yours', 'should', 'needn', 'their', 'from', 'have', 'not', 'shouldn', 'them', 'had', 'y', 'being', "weren't", 'does', 'about', 're', 'between', 'was', 'hers', 'you', 'how', 'am', 'same', 'themselves', 'the', 'other', 'this', "won't", 'll', 'wasn', 'she', 'are', 'ain', 'having', 'some', 'any', 'itself', 'our', "mustn't", 'it', 'to', 's', 'mustn', 'mightn'}

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_sentence(sentence): # input str
    words = gensim.utils.simple_preprocess(str(sentence), deacc=True) # list of strings
    lemmatized_words = []
    for word in words:
        if word not in stop_words: # exclude stopwords
            word, word_class = nltk.pos_tag([word])[0] # return [("word", "word class")]
            wordnet_pos = get_wordnet_pos(word_class)
            lemmatized_words.append(lemmatizer.lemmatize(word, pos=wordnet_pos)) # return lemmatized word
    return lemmatized_words


def determine_sentiment(sentence, positive_words, negative_words): # input str
    lemmatized_words = lemmatize_sentence(sentence) # return list of strings
    positive_count = sum(1 for word in lemmatized_words if word in positive_words) # sum generator
    negative_count = sum(1 for word in lemmatized_words if word in negative_words)

    if negative_count > positive_count:
        return 'Negative'
    elif positive_count > negative_count:
        return 'Positive'
    else:
        return 'Neutral'

# %%
# Test
test_sentence = "Elon Musk's daily $1 million giveaway to registered voters could be illegal, experts say"
result = lemmatize_sentence(test_sentence)
print(result,'\n',type(result))
# Out:
# ['elon', 'musk', 'daily', 'million', 'giveaway', 'register', 'voter', 'could', 'illegal', 'expert', 'say']
#  <class 'list'>

# %%
sentiment_dic_path = r"C:\Users\user\Desktop\Python\Thesis\NLP_update\LM字典情緒詞庫.xlsx"

# original function
positive_set, negative_set = load_sentiment_words(sentiment_dic_path)
print(positive_set, negative_set)

# new function
positive_set_new, negative_set_new = load_sentiment_words_2(sentiment_dic_path)
print(positive_set_new, negative_set_new)
# Out:
# {'TREMENDOUS', 'PROGRESSES', 'BREAKTHROUGH', 'LEADERSHIP', 'ACCOMPLISHING', 'ACCOMPLISHES', 'COLLABORATIONS', 'CONSTRUCTIVE', 'HAPPILY', 'BENEFITING', 'STABILIZE', 'IMPROVES', 'ALLIANCE', 'IMPRESSED', 'ADVANTAGEOUSLY', 'INFLUENTIAL', 'SATISFYING', 'PREMIERE', 'EXCELLING', 'STABILIZED', 'FANTASTIC', 'IDEAL', 'EXCEPTIONAL', 'HIGHEST', 'DELIGHT', 'UPTURNS', 'ATTAINS', 'BOLSTERS', 'ENHANCE', 'REWARDS', 'BRILLIANT', 'SATISFACTION', 'PROSPEROUS', 'INCREDIBLE', 'CREATIVELY', 'VIBRANCY', 'STRENGTHENED', 'COLLABORATOR', 'PROSPERED', 'PLEASANT', 'ENABLES', 'PERFECTLY', 'EASIER', 'PROFICIENT', 'STRONGEST', 'GOOD', 'EMPOWERED', 'ENJOY', 'SUCCESS', 'STABILITY', 'FAVORABLE', 'SMOOTH', 'CONDUCIVE', 'INNOVATION', 'LEADING', 'UNPARALLELED', 'REVOLUTIONIZES', 'BEST', 'EXCLUSIVE', 'DILIGENT', 'ENABLING', 'REBOUNDING', 'BOOMING', 'WINNERS', 'HONORING', 'BENEFITTING', 'EXCELLENCE', 'COLLABORATES', 'STABLE', 'CREATIVE', 'EMPOWER', 'PREEMINENCE', 'ASSURED', 'INVENTION', 'INVENTIONS', 'IMPRESSING', 'INNOVATE', 'BENEFITED', 'STABILIZATION', 'GREATLY', 'SATISFIES', 'DISTINCTIVELY', 'RESOLVE', 'SUCCESSFUL', 'DISTINCTIVE', 'BENEFITTED', 'ENCOURAGES', 'INSPIRATION', 'UNMATCHED', 'ENHANCEMENTS', 'PROFICIENTLY', 'COLLABORATING', 'OUTPERFORMS', 'STRONG', 'ENTHUSIASM', 'PROGRESSING', 'ATTRACTIVE', 'INVENTIVE', 'CONCLUSIVE', 'SATISFY', 'ACHIEVE', 'BENEFICIAL', 'GAIN', 'ATTAINING', 'DISTINCTIONS', 'IMPROVING', 'GREATER', 'INTEGRITY', 'DELIGHTFULLY', 'GAINED', 'GREATNESS', 'EFFICIENT', 'INNOVATING', 'LOYAL', 'PREEMINENT', 'FRIENDLY', 'STABILIZATIONS', 'EMPOWERS', 'DREAM', 'IMPRESS', 'ASSURING', 'EXCEPTIONALLY', 'SUCCEEDING', 'HONORS', 'PRESTIGE', 'PLENTIFUL', 'SMOOTHING', 'ACCOMPLISHMENTS', 'REGAINED', 'ENCOURAGED', 'VERSATILE', 'PROSPERS', 'ENHANCEMENT', 'DESPITE', 'MERITORIOUS', 'PRESTIGIOUS', 'EFFECTIVE', 'GAINS', 'IMPROVEMENTS', 'DESIRABLE', 'SURPASSED', 'INVENTED', 'EXCLUSIVITY', 'UNSURPASSED', 'RECEPTIVE', 'GREAT', 'BENEFICIALLY', 'STRONGER', 'ASSURE', 'BETTER', 'WINNING', 'OUTPERFORMED', 'VERSATILITY', 'SATISFIED', 'ADVANTAGES', 'HONOR', 'DELIGHTS', 'DELIGHTFUL', 'HONORED', 'ACHIEVING', 'PROFITABLE', 'BENEFIT', 'BEAUTIFUL', 'ACHIEVED', 'PROFICIENCY', 'VALUABLE', 'ENJOYMENT', 'INVENTING', 'INVENTIVENESS', 'POSITIVE', 'SATISFACTORILY', 'WORTHY', 'PERFECT', 'HONORABLE', 'POPULAR', 'SURPASSING', 'EMPOWERING', 'SOLVES', 'BOOST', 'SURPASSES', 'ENJOYABLE', 'IMPRESSIVE', 'LUCRATIVE', 'ABUNDANT', 'ACHIEVES', 'PROGRESS', 'GAINING', 'INSPIRATIONAL', 'EXCLUSIVELY', 'EASILY', 'ATTAIN', 'EXCITING', 'ACHIEVEMENT', 'ALLIANCES', 'PROFITABILITY', 'DEPENDABLE', 'STRENGTH', 'DILIGENTLY', 'BOOSTED', 'ABLE', 'TREMENDOUSLY', 'PERFECTED', 'EXCLUSIVENESS', 'ACCOMPLISH', 'REBOUND', 'COLLABORATIVE', 'ENCOURAGEMENT', 'ENCOURAGING', 'ENJOYING', 'ENJOYS', 'PERFECTS', 'EASY', 'SMOOTHS', 'EFFICIENCIES', 'ADEQUATELY', 'INVENT', 'BEAUTIFULLY', 'ADVANTAGED', 'COLLABORATED', 'SUCCEED', 'COURTEOUS', 'ADVANCEMENTS', 'ATTAINMENT', 'ADVANCES', 'INNOVATIVE', 'INNOVATORS', 'TRANSPARENCY', 'FAVORITE', 'OPTIMISTIC', 'OPPORTUNITIES', 'ADVANTAGEOUS', 'INVENTOR', 'COLLABORATION', 'IMPROVEMENT', 'OPPORTUNITY', 'EFFICIENTLY', 'ENHANCED', 'INNOVATES', 'DELIGHTED', 'COMPLIMENTARY', 'CONCLUSIVELY', 'SPECTACULARLY', 'REWARDED', 'IMPROVED', 'ENHANCING', 'SUCCEEDED', 'COMPLIMENTS', 'BOLSTERING', 'PLEASURE', 'ATTRACTIVENESS', 'PROFITABLY', 'COLLABORATORS', 'PROSPERITY', 'PROSPERING', 'BOLSTERED', 'ACCLAIMED', 'ABUNDANCE', 'INSIGHTFUL', 'REVOLUTIONIZED', 'IMPROVE', 'PROGRESSED', 'UPTURN', 'OUTPERFORM', 'PLEASED', 'CHARITABLE', 'WIN', 'OUTPERFORMING', 'IMPRESSES', 'FAVORING', 'EFFICIENCY', 'HAPPY', 'EXCITED', 'COLLABORATE', 'ACHIEVEMENTS', 'IMPRESSIVELY', 'PROACTIVE', 'POSITIVELY', 'VIBRANT', 'DESTINED', 'REVOLUTIONIZING', 'STRENGTHENING', 'SURPASS', 'STRENGTHS', 'EXCITEMENT', 'INVENTORS', 'STRENGTHENS', 'BOOM', 'EXEMPLARY', 'DESIRED', 'COMPLIMENTING', 'DISTINCTIVENESS', 'EXCELS', 'HAPPINESS', 'SPECTACULAR', 'INFORMATIVE', 'DEPENDABILITY', 'ADVANCEMENT', 'STRENGTHEN', 'PREMIER', 'SUPERIOR', 'REWARD', 'ADVANCING' ...
# {'accomplishes', 'innovate', 'strengthen', 'assuring', 'worthy', 'perfected', 'desired', 'perfect', 'boom', 'progresses', 'desirable', 'good', 'honored', 'gaining', 'insightful', 'honorable', 'encourages', 'strengthened', 'collaborate', 'enjoyment', 'smooths', 'happiness', 'satisfied', 'delightful', 'progress', 'invent', 'impressive', 'easily', 'achieved', 'greatly', 'alliance', 'attains', 'achievements', 'improving', 'revolutionizes', 'satisfy', 'prosperity', 'regaining', 'achieves', 'attained', 'collaborations', 'alliances', 'dependability', 'incredible', 'achieving', 'delights', 'surpassed', 'nan', 'succeeded', 'complimented', 'stabilizations', 'enjoys', 'prospers', 'collaboration', 'strengthening', 'exclusively', 'abundant', 'exceptionally', 'inventing', 'favorable', 'success', 'succeed', 'inventor', 'favorably', 'impressively', 'enhancing', 'inspiration', 'advantaged', 'outperforms', 'courteous', 'adequately', 'collaborators', 'best', 'surpassing', 'gained', 'stabilizing', 'preeminence', 'valuable', 'resolve', 'stabilization', 'invented', 'integrity', 'positively', 'diligently', 'enhance', 'attractive', 'excels', 'popularity', 'benefited', 'fantastic', 'successful', 'favored', 'assures', 'favorite', 'accomplishing', 'optimistic', 'attain', 'rebounding', 'delight', 'enhancement', 'excited', 'outperformed', 'conclusively', 'meritorious', 'innovated', 'attaining', 'efficient', 'accomplishment', 'succeeding', 'strengthens', 'distinctiveness', 'loyal', 'encouraging', 'progressing', 'pleasantly', 'innovative', 'inventors', 'inventions', 'proactive', 'successes', 'bolstered', 'premier', 'surpasses', 'rewarding', 'efficiencies', 'enjoyed', 'excitement', 'exclusivity', 'brilliant', 'prospering', 'rebound', 'transparency', 'greatness', 'superior', 'beneficially', 'happily', 'popular', 'honoring', 'innovates', 'complimentary', 'distinctively', 'despite', 'influential', 'beautiful', 'pleasure', 'prosperous', 'compliment', 'gain', 'advantages', 'inventive', 'leading', 'enhanced', 'ingenuity', 'informative', 'accomplish', 'boost', 'enjoyable', 'winner', 'spectacularly', 'enthusiastically', 'successfully', 'delighting', 'dream', 'profitable', 'solves', 'impressing', 'happy', 'empowered', 'profitability', 'advances', 'upturns', 'enjoying', 'lucrative', 'strengths', 'exclusives', 'creative', 'empower', 'revolutionized', 'proficiently', 'acclaimed', 'improvement', 'innovator', 'preeminent', 'delighted', 'improved', 'greatest', 'gains', 'collaborative', 'advancements', 'advantage', 'benefiting', 'accomplished', 'benefit', 'proficiency', 'positive', 'confident', 'perfectly', 'easy', 'stable', 'innovativeness', 'ideal', 'vibrancy', 'empowering', 'enjoyably', 'proactively', 'revolutionize', 'attainments', 'compliments', 'advantageous', 'smooth', 'versatility', 'advancement', 'proficient', 'satisfactory', 'unsurpassed', 'smoothing', 'stronger', 'surpass', 'prospered', 'favorites', 'improvements', 'distinctions', 'opportunities', 'exclusiveness', 'easier', 'satisfies', 'conducive', 'enhances', 'efficiency', 'enhancements', 'progressed', 'rebounded', 'prestigious', 'exemplary', 'better', 'stability', 'creativeness', 'benefitting', 'tremendous', 'innovators', 'leadership', 'prestige', 'improve', 'assure', 'enjoy', 'achievement', 'great', 'innovation', 'favoring', 'empowers', 'distinction', 'vibrant', 'stabilizes', 'happiest', 'honors', 'upturn', 'diligent', 'winning', 'collaborated', 'incredibly', 'rewards', 'win', 'bolstering', 'advancing', 'satisfactorily', 'beneficial', 'collaborates', 'enthusiastic', 'excellent', 'inventiveness', 'assured', 'reward', 'spectacular', 'invention', 'conclusive', 'exceptional', 'highest', 'breakthroughs', 'bolsters', 'satisfying', 'destined', 'effective', 'strongest', 'stabilize', 'collaborator', 'distinctive', 'charitable', 'greater', 'innovating', 'exclusive', 'friendly', 'honor', 'constructively', 'pleasant', 'enthusiasm', 'accomplishments', 'opportunity', 'succeeds', 'advantageously', 'delightfully', 'enabled', ...

# %%
import re
words_lower = []
for word in positive_set:
    if re.search(r'[a-z]', word): # if match, return match object
        words_lower.append(word)
print(words_lower)

words_upper = []
for word in positive_set_new:
    if re.search(r'[A-Z]', word): # if match, return match object
        words_upper.append(word)
print(words_upper)
# Out:
# []
# []

# %%
sentence = "HAPPINESS".lower()
sentiment = determine_sentiment(sentence, positive_set_new, negative_set_new)
print(sentiment)
# Out:
# Positive

# %%
def analyze_csv(input_file, output_file, positive_words, negative_words):
    try:
        df = pd.read_csv(input_file)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df['LM label'] = df['sentence'].apply(lambda x: determine_sentiment(x, positive_words, negative_words))

    try:
        df.to_csv(output_file, index=False)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

    try:
        df = pd.read_csv(output_file)
        print(df.head(5))
    except Exception as e:
        print({e})

# %%
input_file = r"C:\Users\user\Desktop\Python\Thesis\NLP_update\1.csv"
output_file = r"LM labeled file.csv"

analyze_csv(input_file, output_file, positive_set_new, negative_set_new)
# Out:
#                                             sentence  label  LM label
# 0  $2.26 Billion Growth in Global Smart Waste Man...      2   Neutral
# 1  NEW YORK, March 25, 2021 /PRNewswire/ -- Techn...      0  Negative
# 2  The market is segmented by application (collec...      0   Neutral
# 3  The report offers an in-depth analysis of rece...      0   Neutral
# 4                   Download Sample Report Instantly      0   Neutral
